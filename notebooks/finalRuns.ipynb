# %%
from fun.models.spectral_unet import SpectralResUNet, SmallResUNet

# %% [markdown]
# #### FNO-ResNets (former 'heat')

# %%
specRes = SpectralResUNet(1, 1, parametrization='spectral', u_shape = False, kbase1=256, kbase2=256)

# %% [markdown]
# #### FNO-ResUNets

# %%
specResU = SpectralResUNet(1, 1, parametrization='spectral', u_shape = True, kbase1=256, kbase2=256)
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### CNN Transposed (with MaxPool and transposed convolutions)

# %%
smallResU = SmallResUNet(1, 1)
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### CNN Interpolation (trigonometric interpolation)

# %%
spatResU64 = SpectralResUNet(1, 1, parametrization='spatial', u_shape = True, kbase1=64, kbase2=64)
spatResU128 = SpectralResUNet(1, 1, parametrization='spatial', u_shape = True, kbase1=128, kbase2=128)
spatResU256 = SpectralResUNet(1, 1, parametrization='spatial', u_shape = True, kbase1=256, kbase2=256)
# Out:
# <All keys matched successfully>
